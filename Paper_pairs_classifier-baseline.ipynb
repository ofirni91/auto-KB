# %%
def str_to_vec(str_word_vec):
    str_word_vec = str_word_vec[12:-33]
    str_word_vec = re.sub(r'\[', '', str_word_vec)
    str_word_vec = re.sub(r'\]', '', str_word_vec)
    str_word_vec = re.sub(r'\n', ' ', str_word_vec)
    str_word_vec = re.sub(r'\s+', ' ', str_word_vec)
    vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
    return vec

def str_to_vec_rep(str_word_vec):
    str_word_vec = str_word_vec[12:-33]
    str_word_vec = re.sub(r'\[', '', str_word_vec)
    str_word_vec = re.sub(r'\]', '', str_word_vec)
    str_word_vec = re.sub(r'\n', ' ', str_word_vec)
    str_word_vec = re.sub(r'\s+', ' ', str_word_vec)
    vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
    return vec

def str_to_vec_rep_old(str_word_vec):
    str_word_vec = str_word_vec[79:-25]
    str_word_vec = re.sub(r'\[', '', str_word_vec)
    str_word_vec = re.sub(r'\]', '', str_word_vec)
    str_word_vec = re.sub(r'\n', ' ', str_word_vec)
    str_word_vec = re.sub(r'\s+', ' ', str_word_vec)
    vec = np.fromstring(str_word_vec, dtype=float, sep=',')
    return vec

# %%
################################################## LOAD DATA ###########################################################
import pandas as pd
import numpy as np
import re

pos = pd.read_csv('pos_yago_7.csv').sample(frac=1)
neg = pd.read_csv('neg_yago_7.csv').sample(frac=1)

# pos = pd.read_csv('pos_7.csv').sample(frac=1)
# neg = pd.read_csv('neg_7.csv').sample(frac=1)

# pos_unseen = pd.read_csv('zero_shot_pov_pairs.csv')
# neg_unseen = pd.read_csv('zero_shot_neg_pairs.csv')

# pos_train = pd.read_csv('zero_shot_pos_pairs_train.csv')
# neg_train = pd.read_csv('zero_shot_neg_pairs_train.csv')


# pos_train = pd.read_csv("tac_pos_train.csv")
# pos_test = pd.read_csv("tac_pos_test.csv")

# neg_train = pd.read_csv("tac_neg_train.csv")
# neg_test = pd.read_csv("tac_neg_test.csv")

############################################### GENERATE VECTORS #######################################################
from collections import defaultdict

yago_paper_step_1_with_triv = pd.DataFrame()
yago_paper_step_1_non_triv = pd.DataFrame()

auc_lst = []
err_lst = []
precision_lst = []
recall_last = []
f1_lst = []

agg_metrics_with_triv = defaultdict(list)
agg_metrics_non_triv = defaultdict(list)

metrics_with_triv = defaultdict(list)
metrics_non_triv = defaultdict(list)

for prct in [0.99, 0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1]:
    with_trivial = defaultdict(list)
    non_trivial = defaultdict(list)
    for i in range(1, 11):
        final_vecs_pos = []
        final_vecs_neg = []
        pos_labels = []
        neg_labels = []
        
        final_vecs_pos_test = []
        final_vecs_neg_test = []
        pos_labels_test = []
        neg_labels_test = []
        
        y = 0
        # pos_labels = np.array(pos['same_entity'])
        # neg_labels = np.array(neg['same_entity'])

        for index, row in pos.iterrows():
        #     try:
                diff_vec = []
                a_word_vec = str_to_vec_rep(row['a_word_vec'])
                b_word_vec = str_to_vec_rep(row['b_word_vec'])

                diff_vec.append(b_word_vec - a_word_vec)

                diff_vec.append(row['mention_b'])
                diff_vec.append(row['mention_a'])
                diff_vec.append(row['text_b'])
                diff_vec.append(row['text_a'])
                final_vecs_pos.append(diff_vec)
                pos_labels.append(1)
        #     except:
        #         print(index)
        #         print(b_sentence_rep_vec)
        #         print('*************', len(b_sentence_rep_vec), '**************')
        # final_vecs_pos = np.array(final_vecs_pos)

        for index, row in neg.iterrows():
        #     try:
                diff_vec = []
                a_word_vec = str_to_vec_rep(row['a_word_vec'])
                b_word_vec = str_to_vec_rep(row['b_word_vec'])

                diff_vec.append(b_word_vec - a_word_vec)
                                
                diff_vec.append(row['mention_b'])
                diff_vec.append(row['mention_a'])
                diff_vec.append(row['text_b'])
                diff_vec.append(row['text_a'])
                final_vecs_neg.append(diff_vec)
                neg_labels.append(0)
        #     except:
        #         print(index)
        #         print('index_b: ', index)
        # final_vecs_neg = np.array(final_vecs_neg)
        
#         for index, row in pos_test.iterrows():
#         #     try:
#                 diff_vec = []
#                 a_word_vec = str_to_vec_rep(row['a_word_vec'])
#                 b_word_vec = str_to_vec_rep(row['b_word_vec'])

#                 diff_vec.append(b_word_vec - a_word_vec)

#                 diff_vec.append(row['mention_b'])
#                 diff_vec.append(row['mention_a'])
#                 diff_vec.append(row['text_b'])
#                 diff_vec.append(row['text_a'])
#                 final_vecs_pos_test.append(diff_vec)
#                 pos_labels_test.append(1)
#         #     except:
#         #         print(index)
#         #         print(b_sentence_rep_vec)
#         #         print('*************', len(b_sentence_rep_vec), '**************')
#         # final_vecs_pos = np.array(final_vecs_pos)

#         for index, row in neg_test.iterrows():
#         #     try:
#                 diff_vec = []
#                 a_word_vec = str_to_vec_rep(row['a_word_vec'])
#                 b_word_vec = str_to_vec_rep(row['b_word_vec'])

#                 diff_vec.append(b_word_vec - a_word_vec)
                                
#                 diff_vec.append(row['mention_b'])
#                 diff_vec.append(row['mention_a'])
#                 diff_vec.append(row['text_b'])
#                 diff_vec.append(row['text_a'])
#                 final_vecs_neg_test.append(diff_vec)
#                 neg_labels_test.append(0)
#         #     except:
#         #         print(index)
#         #         print('index_b: ', index)
#         # final_vecs_neg = np.array(final_vecs_neg)

        ############################################### VERIFY VECTORS #########################################################


        res_pos = []
        pos_l = []
        for v in final_vecs_pos:
            if len(v[0]) == 512:
                res_pos.append(v)
                pos_l.append(1)

        res_neg = []
        neg_l = []
        for v in final_vecs_neg:
            if len(v[0]) == 512:
                res_neg.append(v)
                neg_l.append(0)

        res_pos = np.array(res_pos)
        res_neg = np.array(res_neg)
        pos_l = np.array(pos_l)
        neg_l = np.array(neg_l)

#         res_pos_test = []
#         pos_l_test = []
#         for v in final_vecs_pos_test:
#             if len(v[0]) == 512:
#                 res_pos_test.append(v)
#                 pos_l_test.append(1)

#         res_neg_test = []
#         neg_l_test = []
#         for v in final_vecs_neg_test:
#             if len(v[0]) == 512:
#                 res_neg_test.append(v)
#                 neg_l_test.append(0)

#         res_pos_test = np.array(res_pos_test)
#         res_neg_test = np.array(res_neg_test)
#         pos_l_test = np.array(pos_l_test)
#         neg_l_test = np.array(neg_l_test)

        ############################################# TRAIN TEST SPLIT #########################################################


        from sklearn.model_selection import train_test_split

        train_features_pos, test_features_pos, train_labels_pos, test_labels_pos = train_test_split(res_pos, pos_l, test_size = prct)
    #     print('POSITIVE')
    #     print('train features: ', train_features_pos.shape)
    #     print('test features: ', test_features_pos.shape)
    #     print('train labels: ', train_labels_pos.shape)
    #     print('test labels: ', test_labels_pos.shape)
    #     print('\n')

        train_features_neg, test_features_neg, train_labels_neg, test_labels_neg = train_test_split(res_neg, neg_l, test_size = prct)
    #     print('NEGATIVE')
    #     print('train features: ', train_features_neg.shape)
    #     print('test features: ', test_features_neg.shape)
    #     print('train labels: ', train_labels_neg.shape)
    #     print('test labels: ', test_labels_neg.shape)
    #     print('\n')

        train_features_pos = list(train_features_pos)
        train_features_pos.extend(list(train_features_neg))
        train_features_list = train_features_pos
        train_features = [x[0] for x in train_features_pos]
        train_features = np.array(train_features_pos)

        test_features_pos = list(test_features_pos)
        test_features_pos.extend(list(test_features_neg))
        test_features_list = test_features_pos
        test_features = [x[0] for x in test_features_pos]
        test_features = np.array(test_features_pos)
        
#         test_features_pos = list(res_pos_test)
#         test_features_pos.extend(list(res_neg_test))
#         test_features_list = test_features_pos
#         test_features = [x[0] for x in test_features_pos]
#         test_features = np.array(test_features_pos)

        train_labels_pos = list(train_labels_pos)
        train_labels_pos.extend(list(train_labels_neg))
        train_labels = np.array(train_labels_pos)

        test_labels_pos = list(test_labels_pos)
        test_labels_pos.extend(list(test_labels_neg))
        test_labels = np.array(test_labels_pos)

    #     print('TOTAL')
    #     print(train_features.shape)
    #     print(test_features.shape)
    #     print(train_labels.shape)
    #     print(test_labels.shape)
    #     print('\n')



        ############################################# ALL DATA RESULTS  ########################################################


        from sklearn.ensemble import RandomForestClassifier
        from sklearn.metrics import f1_score, precision_score, recall_score, confusion_matrix, roc_auc_score
        import pandas as pd
        import pickle

        rf = RandomForestClassifier(n_estimators = 100)
        train_set = [t[0] for t in train_features]
        rf.fit(train_set, train_labels)
        
        with open('rf_tac_baseline.pickle', 'wb') as handle:
            pickle.dump(rf, handle)
            print(rf)
        
        predictions = rf.predict([t[0] for t in test_features])
        predictions_probs = rf.predict_proba([t[0] for t in test_features])
        errors = abs(predictions - test_labels)
        roc_auc = roc_auc_score(test_labels, predictions)

        print('All Results')
        print('roc auc: ', roc_auc)
        print('error: ', sum(errors)/len(predictions))
        print('f1: ', f1_score(test_labels, predictions))
        print('precision :', precision_score(test_labels, predictions))
        print('recall :', recall_score(test_labels, predictions))  
        print('***********************')
        confusion_df = pd.DataFrame(confusion_matrix(test_labels, predictions))
        confusion_df.columns = ['predicted False', 'predicted True']
        confusion_df[''] = ['actual False', 'actual True']
        print(confusion_df.to_string(index=False))
        print('\n\n')

        with_trivial['auc'].append(roc_auc)
        with_trivial['error'].append(sum(errors)/len(predictions))
        with_trivial['precision'].append(precision_score(test_labels, predictions))
        with_trivial['recall'].append(recall_score(test_labels, predictions))
        with_trivial['f1'].append(f1_score(test_labels, predictions))

        ############################################# NON TRIVIAL RESULTS  ########################################################


        from sklearn.ensemble import RandomForestClassifier
        from sklearn.metrics import f1_score, precision_score, recall_score, confusion_matrix, roc_auc_score
        import pandas as pd

        test_features_not_trivial = []
        test_labels_not_trivial = []
        for i, t in enumerate(test_features):
            if (t[1] == t[2] and test_labels[i] == 0) or (t[1] != t[2] and test_labels[i] == 1):
                test_features_not_trivial.append(t)
                test_labels_not_trivial.append(test_labels[i])

        predictions = rf.predict([t[0] for t in test_features_not_trivial])
        predictions_probs = rf.predict_proba([t[0] for t in test_features_not_trivial])
        errors = abs(predictions - test_labels_not_trivial)
        try:
            roc_auc = roc_auc_score(test_labels_not_trivial, predictions)
        except:
            roc_auc = 0.0
        
        finally:
            print('Non Trivial Results')
            print('roc auc: ', roc_auc)
            print('error: ', sum(errors)/len(predictions))
            print('f1: ', f1_score(test_labels_not_trivial, predictions))
            print('precision :', precision_score(test_labels_not_trivial, predictions))
            print('recall :', recall_score(test_labels_not_trivial, predictions))  
            print('***********************')
            confusion_df = pd.DataFrame(confusion_matrix(test_labels_not_trivial, predictions))
            confusion_df.columns = ['predicted False', 'predicted True']
            confusion_df[''] = ['actual False', 'actual True']
            print(confusion_df.to_string(index=False))
            
            non_trivial['auc'].append(roc_auc) 
            non_trivial['error'].append(sum(errors)/len(predictions))
            non_trivial['precision'].append(precision_score(test_labels_not_trivial, predictions))
            non_trivial['recall'].append(recall_score(test_labels_not_trivial, predictions))
            non_trivial['f1'].append(f1_score(test_labels_not_trivial, predictions))


    ############################################# AGGREGATE RESULTS ################################################################

    import statistics
    
    print(f'# Positive Pairs: {prct}')

    for key in with_trivial.keys():
        agg_metrics_with_triv[key].append(statistics.mean(with_trivial[key]))
#         metrics_with_triv[key].append(with_trivial[key])
        
    for key in non_trivial.keys():
        agg_metrics_non_triv[key].append(statistics.mean(non_trivial[key]))
#         metrics_non_triv[key].append(non_trivial[key])
                
    print(agg_metrics_with_triv)
    print(agg_metrics_non_triv)
############################################# SAVE CSVs ################################################################


yago_paper_step_1_with_triv['#_pos_pairs'] = [0.99, 0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1]
yago_paper_step_1_with_triv['auc'] = agg_metrics_with_triv['auc']
yago_paper_step_1_with_triv['error'] = agg_metrics_with_triv['error']
yago_paper_step_1_with_triv['precision'] = agg_metrics_with_triv['precision']
yago_paper_step_1_with_triv['recall'] = agg_metrics_with_triv['recall']
yago_paper_step_1_with_triv['f1'] = agg_metrics_with_triv['f1']
yago_paper_step_1_with_triv.to_csv('baseline_final_2_yago_paper_step_1_with_triv.csv')

yago_paper_step_1_non_triv['#_pos_pairs'] = [0.99, 0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1]
yago_paper_step_1_non_triv['auc'] = agg_metrics_non_triv['auc']
yago_paper_step_1_non_triv['error'] = agg_metrics_non_triv['error']
yago_paper_step_1_non_triv['precision'] = agg_metrics_non_triv['precision']
yago_paper_step_1_non_triv['recall'] = agg_metrics_non_triv['recall']
yago_paper_step_1_non_triv['f1'] = agg_metrics_non_triv['f1']
yago_paper_step_1_non_triv.to_csv('baseline_final_2_yago_paper_step_1_non_triv.csv')
# Out:
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.6881737782540374
# error:  0.31192247013748026
# f1:  0.6797037722749363
# precision : 0.7009546539379475
# recall : 0.6597035040431267
# ***********************
#  predicted False  predicted True
#             3169            1253  actual False
#             1515            2937   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.5180883991530629
# error:  0.48229190164674035
# f1:  0.4770058708414873
# precision : 0.5239118753358409
# recall : 0.43780871127076787
# ***********************
#  predicted False  predicted True
#             1320             886  actual False
#             1252             975   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.6329996976645809
# error:  0.36747802569303584
# f1:  0.5731116638303443
# precision : 0.6868528396611233
# recall : 0.4916891284815813
# ***********************
#  predicted False  predicted True
#             3424             998  actual False
#             2263            2189   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.38409520557134325
# error:  0.616546438232642
# f1:  0.25130030112236523
# precision : 0.32165381920112124
# recall : 0.20619946091644206
# ***********************
#  predicted False  predicted True
#             1242             968  actual False
#             1767             459   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.6781601365873402
# error:  0.32217714672075726
# f1:  0.6430265950805344
# precision : 0.7239246556086589
# recall : 0.5783917340521114
# ***********************
#  predicted False  predicted True
#             3440             982  actual False
#             1877            2575   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.48544529122241353
# error:  0.5152267087750959
# f1:  0.4098191214470284
# precision : 0.48294762484774667
# recall : 0.3559245960502693
# ***********************
#  predicted False  predicted True
#             1356             849  actual False
#             1435             793   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.6807869803152822
# error:  0.31947261663286003
# f1:  0.6548155363448191
# precision : 0.714969423025791
# recall : 0.6039982030548068
# ***********************
#  predicted False  predicted True
#             3350            1072  actual False
#             1763            2689   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.5722988790657964
# error:  0.4281842818428184
# f1:  0.5153374233128835
# precision : 0.5968028419182948
# recall : 0.4534412955465587
# ***********************
#  predicted False  predicted True
#             1524             681  actual False
#             1215            1008   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.6378015582465034
# error:  0.3626324092855533
# f1:  0.5849883930874388
# precision : 0.6868564506359782
# recall : 0.5094339622641509
# ***********************
#  predicted False  predicted True
#             3388            1034  actual False
#             2184            2268   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.3659742426297024
# error:  0.6346023879252084
# f1:  0.23596419853539466
# precision : 0.2979452054794521
# recall : 0.1953300404131118
# ***********************
#  predicted False  predicted True
#             1187            1025  actual False
#             1792             435   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.6836064409635236
# error:  0.3159792652693261
# f1:  0.7190943698657585
# precision : 0.6490054249547921
# recall : 0.8061545372866128
# ***********************
#  predicted False  predicted True
#             2481            1941  actual False
#              863            3589   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.6671546388557186
# error:  0.33258071799503275
# f1:  0.6954724002480877
# precision : 0.6429663608562691
# recall : 0.7573165240882486
# ***********************
#  predicted False  predicted True
#             1274             934  actual False
#              539            1682   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.695923713946806
# error:  0.30392156862745096
# f1:  0.7100311794430706
# precision : 0.6809651474530831
# recall : 0.7416891284815813
# ***********************
#  predicted False  predicted True
#             2875            1547  actual False
#             1150            3302   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.5241133334311252
# error:  0.47573911081020087
# f1:  0.5449050086355787
# precision : 0.5238688252386883
# recall : 0.5677013045434098
# ***********************
#  predicted False  predicted True
#             1061            1147  actual False
#              961            1262   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.6766932612117067
# error:  0.3236421005183683
# f1:  0.6416271524831544
# precision : 0.7217855137563167
# recall : 0.5774932614555256
# ***********************
#  predicted False  predicted True
#             3431             991  actual False
#             1881            2571   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.5514057926006629
# error:  0.44923285198555957
# f1:  0.4683578104138852
# precision : 0.5769736842105263
# recall : 0.3941573033707865
# ***********************
#  predicted False  predicted True
#             1564             643  actual False
#             1348             877   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.6419806139603381
# error:  0.35789948163173313
# f1:  0.6550825369244135
# precision : 0.6341463414634146
# recall : 0.6774483378256964
# ***********************
#  predicted False  predicted True
#             2682            1740  actual False
#             1436            3016   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.6143152130879893
# error:  0.3855367231638418
# f1:  0.6335910652920963
# precision : 0.6052523594583504
# recall : 0.6647138350608383
# ***********************
#  predicted False  predicted True
#             1244             962  actual False
#              744            1475   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.667905723770269
# error:  0.33186837953572235
# f1:  0.6895752081796142
# precision : 0.6496524329692155
# recall : 0.7347259658580413
# ***********************
#  predicted False  predicted True
#             2658            1764  actual False
#             1181            3271   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.5203858598305106
# error:  0.4794489611562782
# f1:  0.5610915856936117
# precision : 0.5181366933944254
# recall : 0.6118124436429215
# ***********************
#  predicted False  predicted True
#              948            1262  actual False
#              861            1357   actual True
# # Positive Pairs: 0.99
# defaultdict(<class 'list'>, {'auc': [0.6684031904920388], 'error': [0.33169934640522875], 'precision': [0.6849112883466321], 'recall': [0.6380727762803234], 'f1': [0.6551056407514084]})
# defaultdict(<class 'list'>, {'auc': [0.5203276855448326], 'error': [0.4799390083533418], 'precision': [0.5090459289940715], 'recall': [0.4644405514903355], 'f1': [0.4792844785542419]})
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.7909929595904834
# error:  0.20887566629478121
# f1:  0.7995240928019036
# precision : 0.7709958696649839
# recall : 0.8302446256486287
# ***********************
#  predicted False  predicted True
#             3022             998  actual False
#              687            3360   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.602048059579915
# error:  0.3983259478089611
# f1:  0.6317705962676377
# precision : 0.5851602023608768
# recall : 0.6864490603363007
# ***********************
#  predicted False  predicted True
#             1056             984  actual False
#              634            1388   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.8042922894792162
# error:  0.1956117515805132
# f1:  0.8103365384615384
# precision : 0.7889070910367423
# recall : 0.8329626884111687
# ***********************
#  predicted False  predicted True
#             3118             902  actual False
#              676            3371   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.6351305297926102
# error:  0.36460660213452467
# f1:  0.6601896830904465
# precision : 0.6201651455888744
# recall : 0.7057368941641938
# ***********************
#  predicted False  predicted True
#             1133             874  actual False
#              595            1427   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.7978926715569669
# error:  0.20205776620800794
# f1:  0.8014132553606238
# precision : 0.7904349915885605
# recall : 0.8127007659995058
# ***********************
#  predicted False  predicted True
#             3148             872  actual False
#              758            3289   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.6253289715413898
# error:  0.37465973768869093
# f1:  0.6417415996213913
# precision : 0.6149659863945578
# recall : 0.6709549727857497
# ***********************
#  predicted False  predicted True
#             1171             849  actual False
#              665            1356   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.8047798442922525
# error:  0.19511590430147516
# f1:  0.8112709832134293
# precision : 0.7880270207314233
# recall : 0.8359278477884853
# ***********************
#  predicted False  predicted True
#             3110             910  actual False
#              664            3383   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.639822309970385
# error:  0.3596621957277695
# f1:  0.6681943171402384
# precision : 0.6236099230111206
# recall : 0.71964461994077
# ***********************
#  predicted False  predicted True
#             1120             880  actual False
#              568            1458   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.8126222114040619
# error:  0.18718234783686624
# f1:  0.8235981308411214
# precision : 0.7810768889873698
# recall : 0.8710155670867309
# ***********************
#  predicted False  predicted True
#             3032             988  actual False
#              522            3525   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.6500521390959637
# error:  0.35012468827930177
# f1:  0.6866071428571429
# precision : 0.6206618240516546
# recall : 0.7682317682317682
# ***********************
#  predicted False  predicted True
#             1068             940  actual False
#              464            1538   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.8151288590406013
# error:  0.18470311144167598
# f1:  0.8245820579232398
# precision : 0.7874971891162581
# recall : 0.8653323449468743
# ***********************
#  predicted False  predicted True
#             3075             945  actual False
#              545            3502   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.6553992717471268
# error:  0.34385877672799603
# f1:  0.6905347952562094
# precision : 0.631342062193126
# recall : 0.7619753086419753
# ***********************
#  predicted False  predicted True
#             1096             901  actual False
#              482            1543   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.7924192049389818
# error:  0.20751208627742657
# f1:  0.7971892415798401
# precision : 0.7820299500831946
# recall : 0.8129478626142822
# ***********************
#  predicted False  predicted True
#             3103             917  actual False
#              757            3290   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.6121019844115446
# error:  0.38744749196936
# f1:  0.6356877323420074
# precision : 0.6039735099337749
# recall : 0.6709171162334477
# ***********************
#  predicted False  predicted True
#             1111             897  actual False
#              671            1368   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.8101587134748791
# error:  0.18966158423205653
# f1:  0.8204646796526637
# precision : 0.7812290502793297
# recall : 0.863849765258216
# ***********************
#  predicted False  predicted True
#             3041             979  actual False
#              551            3496   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.6422712390057805
# error:  0.3572849328692193
# f1:  0.6793126534255747
# precision : 0.6181965881397238
# recall : 0.753838533927687
# ***********************
#  predicted False  predicted True
#             1063             940  actual False
#              497            1522   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.7923271891100465
# error:  0.20763604809718605
# f1:  0.7951571480983245
# precision : 0.7871670702179177
# recall : 0.8033110946380034
# ***********************
#  predicted False  predicted True
#             3141             879  actual False
#              796            3251   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.615012101508504
# error:  0.3848245180425111
# f1:  0.6313047596495382
# precision : 0.6081204379562044
# recall : 0.6563269325455441
# ***********************
#  predicted False  predicted True
#             1156             859  actual False
#              698            1333   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.8198394609605789
# error:  0.17999256229081442
# f1:  0.8290558040970096
# precision : 0.7917697324038677
# recall : 0.8700271806276254
# ***********************
#  predicted False  predicted True
#             3094             926  actual False
#              526            3521   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.6682756122849017
# error:  0.3316708229426434
# f1:  0.7005853219270598
# precision : 0.638752052545156
# recall : 0.7756729810568295
# ***********************
#  predicted False  predicted True
#             1124             880  actual False
#              450            1556   actual True
# # Positive Pairs: 0.9
# defaultdict(<class 'list'>, {'auc': [0.6684031904920388, 0.8040453403848068], 'error': [0.33169934640522875, 0.19583488285608033], 'precision': [0.6849112883466321, 0.7849134854109647], 'recall': [0.6380727762803234, 0.8398319743019521], 'f1': [0.6551056407514084, 0.8112591932029695]})
# defaultdict(<class 'list'>, {'auc': [0.5203276855448326, 0.6345442218938121], 'error': [0.4799390083533418, 0.3652465714190978], 'precision': [0.5090459289940715, 0.6164947732175069], 'recall': [0.4644405514903355, 0.7169748187864265], 'f1': [0.4792844785542419, 0.6625928601577247]})
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.813273118960268
# error:  0.18661087866108786
# f1:  0.8201129335842968
# precision : 0.7940640458214007
# recall : 0.8479288295802058
# ***********************
#  predicted False  predicted True
#             2782             791  actual False
#              547            3050   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.6486934486067661
# error:  0.3511640798226164
# f1:  0.6768681458811528
# precision : 0.6277199621570483
# recall : 0.7343663530713891
# ***********************
#  predicted False  predicted True
#             1014             787  actual False
#              480            1327   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.8239867535848864
# error:  0.17587168758716876
# f1:  0.8317095956225811
# precision : 0.7997946611909651
# recall : 0.8662774534334168
# ***********************
#  predicted False  predicted True
#             2793             780  actual False
#              481            3116   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.6611232912410703
# error:  0.33884992987377277
# f1:  0.6907322068612392
# precision : 0.6354215732454075
# recall : 0.7565900168255749
# ***********************
#  predicted False  predicted True
#             1008             774  actual False
#              434            1349   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.8167435686096282
# error:  0.18312412831241284
# f1:  0.8243008162719122
# precision : 0.7946336429308566
# recall : 0.8562691131498471
# ***********************
#  predicted False  predicted True
#             2777             796  actual False
#              517            3080   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.649059828419623
# error:  0.35083798882681566
# f1:  0.6787723785166241
# precision : 0.6265344664778093
# recall : 0.7405133928571429
# ***********************
#  predicted False  predicted True
#              997             791  actual False
#              465            1327   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.820925848506557
# error:  0.1789400278940028
# f1:  0.8284071151531364
# precision : 0.7981958762886598
# recall : 0.8609952738393105
# ***********************
#  predicted False  predicted True
#             2790             783  actual False
#              500            3097   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.6567919277308448
# error:  0.34318371898522443
# f1:  0.6844398872084082
# precision : 0.6336022781205506
# recall : 0.7441471571906354
# ***********************
#  predicted False  predicted True
#             1021             772  actual False
#              459            1335   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.8219781294562336
# error:  0.17782426778242677
# f1:  0.8325233153815842
# precision : 0.789093625498008
# recall : 0.8810119544064499
# ***********************
#  predicted False  predicted True
#             2726             847  actual False
#              428            3169   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.6645009370375639
# error:  0.3359396816531695
# f1:  0.6997753930621411
# precision : 0.6306792622582096
# recall : 0.7858744394618834
# ***********************
#  predicted False  predicted True
#              976             821  actual False
#              382            1402   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.8221638192289638
# error:  0.17768479776847979
# f1:  0.8304498269896194
# precision : 0.7965279550676538
# recall : 0.8673894912427023
# ***********************
#  predicted False  predicted True
#             2776             797  actual False
#              477            3120   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.6581090042353
# error:  0.3420022371364653
# f1:  0.6887248663782134
# precision : 0.6313579094727019
# recall : 0.7575587905935051
# ***********************
#  predicted False  predicted True
#             1000             790  actual False
#              433            1353   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.8171316380592373
# error:  0.18270571827057183
# f1:  0.8262138498275403
# precision : 0.7901547830499873
# recall : 0.8657214345287739
# ***********************
#  predicted False  predicted True
#             2746             827  actual False
#              483            3114   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.6470591138627453
# error:  0.3524021105248542
# f1:  0.6812358703843255
# precision : 0.6245969599263013
# recall : 0.7491712707182321
# ***********************
#  predicted False  predicted True
#              976             815  actual False
#              454            1356   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.8238010638121562
# error:  0.17601115760111577
# f1:  0.83377239199157
# precision : 0.7922403003754693
# recall : 0.8798999165971643
# ***********************
#  predicted False  predicted True
#             2743             830  actual False
#              432            3165   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.6617009778045899
# error:  0.33856502242152464
# f1:  0.696939287506272
# precision : 0.6296464188576609
# recall : 0.7803370786516854
# ***********************
#  predicted False  predicted True
#              971             817  actual False
#              391            1389   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.826039144944698
# error:  0.17377963737796373
# f1:  0.8355766693058855
# precision : 0.7952775684501382
# recall : 0.8801779260494856
# ***********************
#  predicted False  predicted True
#             2758             815  actual False
#              431            3166   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.6658880494613819
# error:  0.33445661331086773
# f1:  0.6985573272589218
# precision : 0.6341911764705882
# recall : 0.7774647887323943
# ***********************
#  predicted False  predicted True
#              990             796  actual False
#              395            1380   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.8217150592188145
# error:  0.17810320781032077
# f1:  0.8315081145269824
# precision : 0.7913108990457057
# recall : 0.876007784264665
# ***********************
#  predicted False  predicted True
#             2742             831  actual False
#              446            3151   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.6633111093736601
# error:  0.3368893879842785
# f1:  0.6986438975389252
# precision : 0.6311252268602541
# recall : 0.7823397075365579
# ***********************
#  predicted False  predicted True
#              971             813  actual False
#              387            1391   actual True
# # Positive Pairs: 0.8
# defaultdict(<class 'list'>, {'auc': [0.6684031904920388, 0.8040453403848068, 0.8207758144381443], 'error': [0.33169934640522875, 0.19583488285608033, 0.1790655509065551], 'precision': [0.6849112883466321, 0.7849134854109647, 0.7941293357718845], 'recall': [0.6380727762803234, 0.8398319743019521, 0.8681679177092021], 'f1': [0.6551056407514084, 0.8112591932029695, 0.8294574628655108]})
# defaultdict(<class 'list'>, {'auc': [0.5203276855448326, 0.6345442218938121, 0.6576237687773545], 'error': [0.4799390083533418, 0.3652465714190978, 0.3424290770539589], 'precision': [0.5090459289940715, 0.6164947732175069, 0.6304875233846532], 'recall': [0.4644405514903355, 0.7169748187864265, 0.7608362995639001], 'f1': [0.4792844785542419, 0.6625928601577247, 0.6894689260596223]})
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.8238644421318768
# error:  0.17593625498007967
# f1:  0.8343834383438342
# precision : 0.790505969300739
# recall : 0.883418043202033
# ***********************
#  predicted False  predicted True
#             2390             737  actual False
#              367            2781   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.6627700559610548
# error:  0.33779477374123645
# f1:  0.6993760635280771
# precision : 0.6278004073319755
# recall : 0.7893725992317542
# ***********************
#  predicted False  predicted True
#              845             731  actual False
#              329            1233   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.8319978898384323
# error:  0.16780876494023905
# f1:  0.8417731029301276
# precision : 0.7986883376104933
# recall : 0.8897712833545108
# ***********************
#  predicted False  predicted True
#             2421             706  actual False
#              347            2801   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.6766105192873835
# error:  0.3231552162849873
# f1:  0.7125070741369552
# precision : 0.6426748340990301
# recall : 0.7993650793650794
# ***********************
#  predicted False  predicted True
#              869             700  actual False
#              316            1259   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.8232899178325109
# error:  0.17657370517928286
# f1:  0.8307880268784362
# precision : 0.8
# recall : 0.8640406607369758
# ***********************
#  predicted False  predicted True
#             2447             680  actual False
#              428            2720   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.668444788042778
# error:  0.33248730964467005
# f1:  0.6935672514619883
# precision : 0.6376344086021506
# recall : 0.7602564102564102
# ***********************
#  predicted False  predicted True
#              918             674  actual False
#              374            1186   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.8325031827152859
# error:  0.16733067729083664
# f1:  0.8410054512416717
# precision : 0.8035300925925926
# recall : 0.8821473951715375
# ***********************
#  predicted False  predicted True
#             2448             679  actual False
#              371            2777   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.6778401778878265
# error:  0.3219527760051053
# f1:  0.7098073051481162
# precision : 0.6470896696381752
# recall : 0.7859872611464969
# ***********************
#  predicted False  predicted True
#              891             673  actual False
#              336            1234   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.8310918369295748
# error:  0.16876494023904381
# f1:  0.838591678097851
# precision : 0.806035745678289
# recall : 0.8738881829733164
# ***********************
#  predicted False  predicted True
#             2465             662  actual False
#              397            2751   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.6777612634473833
# error:  0.3214626391096979
# f1:  0.7085615451138657
# precision : 0.6523354564755839
# recall : 0.7753943217665615
# ***********************
#  predicted False  predicted True
#              905             655  actual False
#              356            1229   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.8305705441274891
# error:  0.16924302788844622
# f1:  0.8401084010840109
# precision : 0.7985117344018318
# recall : 0.886277001270648
# ***********************
#  predicted False  predicted True
#             2423             704  actual False
#              358            2790   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.6766787040437426
# error:  0.3225806451612903
# f1:  0.7135564378899603
# precision : 0.6447975397232188
# recall : 0.7987301587301587
# ***********************
#  predicted False  predicted True
#              863             693  actual False
#              317            1258   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.8215118436017974
# error:  0.17832669322709163
# f1:  0.8303260045489007
# precision : 0.7943138961415723
# recall : 0.8697585768742059
# ***********************
#  predicted False  predicted True
#             2418             709  actual False
#              410            2738   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.6600161406940009
# error:  0.3390804597701149
# f1:  0.695702005730659
# precision : 0.6352694924123495
# recall : 0.7688410386320456
# ***********************
#  predicted False  predicted True
#              856             697  actual False
#              365            1214   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.8292870961568077
# error:  0.17051792828685258
# f1:  0.8392910784019225
# precision : 0.796011396011396
# recall : 0.8875476493011436
# ***********************
#  predicted False  predicted True
#             2411             716  actual False
#              354            2794   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.6741777988248593
# error:  0.3263291945240369
# f1:  0.7085584304805231
# precision : 0.6379928315412187
# recall : 0.7966751918158568
# ***********************
#  predicted False  predicted True
#              870             707  actual False
#              318            1246   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.832649213778912
# error:  0.16717131474103586
# f1:  0.8417559209533866
# precision : 0.8014938236139041
# recall : 0.886277001270648
# ***********************
#  predicted False  predicted True
#             2436             691  actual False
#              358            2790   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.6756307013442843
# error:  0.324002574002574
# f1:  0.7097146151628712
# precision : 0.6445026178010471
# recall : 0.7896087235407312
# ***********************
#  predicted False  predicted True
#              870             679  actual False
#              328            1231   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.8270805286903548
# error:  0.17274900398406373
# f1:  0.8360556563823353
# precision : 0.7979214780600462
# recall : 0.8780177890724269
# ***********************
#  predicted False  predicted True
#             2427             700  actual False
#              384            2764   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.6693079636748928
# error:  0.33099713284485505
# f1:  0.7003172771848861
# precision : 0.6382754994742377
# recall : 0.7757188498402556
# ***********************
#  predicted False  predicted True
#              886             688  actual False
#              351            1214   actual True
# # Positive Pairs: 0.7
# defaultdict(<class 'list'>, {'auc': [0.6684031904920388, 0.8040453403848068, 0.8207758144381443, 0.8283846495803042], 'error': [0.33169934640522875, 0.19583488285608033, 0.1790655509065551, 0.1714422310756972], 'precision': [0.6849112883466321, 0.7849134854109647, 0.7941293357718845, 0.7987012473410864], 'recall': [0.6380727762803234, 0.8398319743019521, 0.8681679177092021, 0.8801143583227446], 'f1': [0.6551056407514084, 0.8112591932029695, 0.8294574628655108, 0.8374078758862477]})
# defaultdict(<class 'list'>, {'auc': [0.5203276855448326, 0.6345442218938121, 0.6576237687773545, 0.6719238113208206], 'error': [0.4799390083533418, 0.3652465714190978, 0.3424290770539589, 0.32798427210885683], 'precision': [0.5090459289940715, 0.6164947732175069, 0.6304875233846532, 0.6408372757098987], 'recall': [0.4644405514903355, 0.7169748187864265, 0.7608362995639001, 0.783994963432535], 'f1': [0.4792844785542419, 0.6625928601577247, 0.6894689260596223, 0.7051668005837902]})
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.8213025403007203
# error:  0.17850502045370026
# f1:  0.8316380217467554
# precision : 0.7892809587217043
# recall : 0.8787991104521868
# ***********************
#  predicted False  predicted True
#             2047             633  actual False
#              327            2371   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.6617435668587562
# error:  0.339436103991212
# f1:  0.6949654491609082
# precision : 0.6259632483698874
# recall : 0.7810650887573964
# ***********************
#  predicted False  predicted True
#              748             631  actual False
#              296            1056   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.8385935408207296
# error:  0.16121234659724804
# f1:  0.8480280455740579
# precision : 0.8044562687063519
# recall : 0.896590066716086
# ***********************
#  predicted False  predicted True
#             2092             588  actual False
#              279            2419   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.6986471874315218
# error:  0.3016344725111441
# f1:  0.7318361955085866
# precision : 0.657566765578635
# recall : 0.8250186150409531
# ***********************
#  predicted False  predicted True
#              772             577  actual False
#              235            1108   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.8291296482745648
# error:  0.1706954258088509
# f1:  0.8382093761015158
# precision : 0.7990591397849462
# recall : 0.8813936249073387
# ***********************
#  predicted False  predicted True
#             2082             598  actual False
#              320            2378   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.6672988707301676
# error:  0.3318352059925094
# f1:  0.7038770053475936
# precision : 0.639344262295082
# recall : 0.7828996282527881
# ***********************
#  predicted False  predicted True
#              731             594  actual False
#              292            1053   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.8287565139462068
# error:  0.1710673112681294
# f1:  0.8379140239605356
# precision : 0.7985224983210208
# recall : 0.8813936249073387
# ***********************
#  predicted False  predicted True
#             2080             600  actual False
#              320            2378   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.6668982128767009
# error:  0.3314732142857143
# f1:  0.7052596758187231
# precision : 0.6421686746987951
# recall : 0.7820983125458547
# ***********************
#  predicted False  predicted True
#              731             594  actual False
#              297            1066   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.8309704258544196
# error:  0.16883599851245817
# f1:  0.8408134642356242
# precision : 0.7977378576180971
# recall : 0.8888065233506302
# ***********************
#  predicted False  predicted True
#             2072             608  actual False
#              300            2398   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.674737489193287
# error:  0.3253500368459838
# f1:  0.7090609555189455
# precision : 0.6408576533650983
# recall : 0.7935103244837758
# ***********************
#  predicted False  predicted True
#              755             603  actual False
#              280            1076   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.8320873394333005
# error:  0.16772034213462253
# f1:  0.8418098912662224
# precision : 0.7989347536617842
# recall : 0.8895478131949592
# ***********************
#  predicted False  predicted True
#             2076             604  actual False
#              298            2400   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.6747348854551636
# error:  0.32432432432432434
# f1:  0.7120315581854044
# precision : 0.6442593694229625
# recall : 0.7957384276267451
# ***********************
#  predicted False  predicted True
#              742             598  actual False
#              278            1083   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.8315388402686346
# error:  0.16827817032354034
# f1:  0.8408651310005275
# precision : 0.7999330879892941
# recall : 0.8862120088954781
# ***********************
#  predicted False  predicted True
#             2082             598  actual False
#              307            2391   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.6787500393424333
# error:  0.32154696132596683
# f1:  0.7112140258021833
# precision : 0.6440982624325944
# recall : 0.7939438700147711
# ***********************
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
#  predicted False  predicted True
#              767             594  actual False
#              279            1075   actual True
# RandomForestClassifier()
# All Results
# roc auc:  0.8322838642222542
# error:  0.16753439940498327
# f1:  0.8415127528583993
# precision : 0.8008034817542685
# recall : 0.8865826538176427
# ***********************
#  predicted False  predicted True
#             2085             595  actual False
#              306            2392   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.6742140045427917
# error:  0.3241405364563657
# f1:  0.714
# precision : 0.6455696202531646
# recall : 0.7986577181208053
# ***********************
#  predicted False  predicted True
#              718             588  actual False
#              270            1071   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.8313448048858745
# error:  0.16846411305317963
# f1:  0.8410526315789474
# precision : 0.7984676882078614
# recall : 0.8884358784284655
# ***********************
#  predicted False  predicted True
#             2075             605  actual False
#              301            2397   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.6730878113224739
# error:  0.32547864506627394
# f1:  0.711864406779661
# precision : 0.6446280991735537
# recall : 0.7947598253275109
# ***********************
#  predicted False  predicted True
#              740             602  actual False
#              282            1092   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.8315251485345696
# error:  0.16827817032354034
# f1:  0.8414783674899281
# precision : 0.7977416140817004
# recall : 0.8902891030392883
# ***********************
#  predicted False  predicted True
#             2071             609  actual False
#              296            2402   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.672611166983693
# error:  0.3282185628742515
# f1:  0.7065908330545333
# precision : 0.6353790613718412
# recall : 0.7957799547852299
# ***********************
#  predicted False  predicted True
#              739             606  actual False
#              271            1056   actual True
# # Positive Pairs: 0.6
# defaultdict(<class 'list'>, {'auc': [0.6684031904920388, 0.8040453403848068, 0.8207758144381443, 0.8283846495803042, 0.8307532666541274], 'error': [0.33169934640522875, 0.19583488285608033, 0.1790655509065551, 0.1714422310756972, 0.1690591297880253], 'precision': [0.6849112883466321, 0.7849134854109647, 0.7941293357718845, 0.7987012473410864, 0.7984937348847029], 'recall': [0.6380727762803234, 0.8398319743019521, 0.8681679177092021, 0.8801143583227446, 0.8868050407709415], 'f1': [0.6551056407514084, 0.8112591932029695, 0.8294574628655108, 0.8374078758862477, 0.8403321705812513]})
# ...
# f1:  0.7333333333333334
# precision : 0.6592465753424658
# recall : 0.8261802575107297
# ***********************
#  predicted False  predicted True
#              246             199  actual False
#               81             385   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.8403467561521253
# error:  0.15942028985507245
# f1:  0.8513513513513513
# precision : 0.7998046875
# recall : 0.91
# ***********************
#  predicted False  predicted True
#              689             205  actual False
#               81             819   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.7068884408602151
# error:  0.29523809523809524
# f1:  0.7370405278039586
# precision : 0.6560402684563759
# recall : 0.8408602150537634
# ***********************
#  predicted False  predicted True
#              275             205  actual False
#               74             391   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.8498657718120806
# error:  0.14994425863991082
# f1:  0.8584955286691216
# precision : 0.8151848151848152
# recall : 0.9066666666666666
# ***********************
#  predicted False  predicted True
#              709             185  actual False
#               84             816   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.7066518847006651
# error:  0.29180695847362514
# f1:  0.7425742574257425
# precision : 0.6708407871198568
# recall : 0.8314855875831486
# ***********************
#  predicted False  predicted True
#              256             184  actual False
#               76             375   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.8515436241610739
# error:  0.14827201783723523
# f1:  0.8598524762908324
# precision : 0.8176352705410822
# recall : 0.9066666666666666
# ***********************
#  predicted False  predicted True
#              712             182  actual False
#               84             816   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.7092743247640743
# error:  0.28859060402684567
# f1:  0.7450592885375494
# precision : 0.6768402154398564
# recall : 0.8285714285714286
# ***********************
#  predicted False  predicted True
#              259             180  actual False
#               78             377   actual True
# # Positive Pairs: 0.2
# defaultdict(<class 'list'>, {'auc': [0.6684031904920388, 0.8040453403848068, 0.8207758144381443, 0.8283846495803042, 0.8307532666541274, 0.8352079691078341, 0.8387192660972815, 0.8416024860869854, 0.8419202087994034], 'error': [0.33169934640522875, 0.19583488285608033, 0.1790655509065551, 0.1714422310756972, 0.1690591297880253, 0.16460611470653871, 0.16107083100948133, 0.15820007437709185, 0.15785953177257525], 'precision': [0.6849112883466321, 0.7849134854109647, 0.7941293357718845, 0.7987012473410864, 0.7984937348847029, 0.8027865456106742, 0.802047350058618, 0.8066546839972406, 0.8032708341399797], 'recall': [0.6380727762803234, 0.8398319743019521, 0.8681679177092021, 0.8801143583227446, 0.8868050407709415, 0.8907473309608541, 0.9014452473596443, 0.9005930318754634, 0.9077777777777778], 'f1': [0.6551056407514084, 0.8112591932029695, 0.8294574628655108, 0.8374078758862477, 0.8403321705812513, 0.8444586078639099, 0.8488380923878529, 0.8510063429773407, 0.8522936087794106]})
# defaultdict(<class 'list'>, {'auc': [0.5203276855448326, 0.6345442218938121, 0.6576237687773545, 0.6719238113208206, 0.6742723234736989, 0.6797920384059583, 0.6869605694857547, 0.6929823509501478, 0.6942894183582687], 'error': [0.4799390083533418, 0.3652465714190978, 0.3424290770539589, 0.32798427210885683, 0.3253438063673746, 0.3197728167869358, 0.31284604064858135, 0.3069886853740111, 0.3063592089662329], 'precision': [0.5090459289940715, 0.6164947732175069, 0.6304875233846532, 0.6408372757098987, 0.6419835016961614, 0.6469769017044635, 0.648554997790102, 0.6543910479554579, 0.6511019329093483], 'recall': [0.4644405514903355, 0.7169748187864265, 0.7608362995639001, 0.783994963432535, 0.7943471764955831, 0.799296592242582, 0.8179682801567416, 0.8201007323495281, 0.8299119445746774], 'f1': [0.4792844785542419, 0.6625928601577247, 0.6894689260596223, 0.7051668005837902, 0.7100700105176538, 0.7150451610434234, 0.7234555956411639, 0.7277824123636178, 0.7295820779158967]})
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.8693064876957495
# error:  0.13043478260869565
# f1:  0.8792569659442724
# precision : 0.8208092485549133
# recall : 0.9466666666666667
# ***********************
#  predicted False  predicted True
#              354              93  actual False
#               24             426   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.7327066373777835
# error:  0.2691415313225058
# f1:  0.7661290322580646
# precision : 0.6713780918727915
# recall : 0.892018779342723
# ***********************
#  predicted False  predicted True
#              125              93  actual False
#               23             190   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.8537434750186427
# error:  0.14604236343366778
# f1:  0.8631138975966564
# precision : 0.814595660749507
# recall : 0.9177777777777778
# ***********************
#  predicted False  predicted True
#              353              94  actual False
#               37             413   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.7052436727359328
# error:  0.29069767441860467
# f1:  0.7504990019960079
# precision : 0.6714285714285714
# recall : 0.8506787330316742
# ***********************
#  predicted False  predicted True
#              117              92  actual False
#               33             188   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.8470171513795676
# error:  0.1527313266443701
# f1:  0.8583247156153051
# precision : 0.8027079303675049
# recall : 0.9222222222222223
# ***********************
#  predicted False  predicted True
#              345             102  actual False
#               35             415   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.7020613415343696
# error:  0.30296127562642367
# f1:  0.7302231237322515
# precision : 0.6405693950177936
# recall : 0.8490566037735849
# ***********************
#  predicted False  predicted True
#              126             101  actual False
#               32             180   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.855973154362416
# error:  0.14381270903010032
# f1:  0.8652037617554857
# precision : 0.8165680473372781
# recall : 0.92
# ***********************
#  predicted False  predicted True
#              354              93  actual False
#               36             414   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.7252822703692401
# error:  0.27292576419213976
# f1:  0.7619047619047619
# precision : 0.6825938566552902
# recall : 0.8620689655172413
# ***********************
#  predicted False  predicted True
#              133              93  actual False
#               32             200   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.8347576435495897
# error:  0.16499442586399107
# f1:  0.846790890269151
# precision : 0.7926356589147286
# recall : 0.9088888888888889
# ***********************
#  predicted False  predicted True
#              340             107  actual False
#               41             409   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.7016228509752526
# error:  0.3048245614035088
# f1:  0.7269155206286837
# precision : 0.6357388316151202
# recall : 0.8486238532110092
# ***********************
#  predicted False  predicted True
#              132             106  actual False
#               33             185   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.83137956748695
# error:  0.16833890746934224
# f1:  0.8451282051282052
# precision : 0.7847619047619048
# recall : 0.9155555555555556
# ***********************
#  predicted False  predicted True
#              334             113  actual False
#               38             412   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.6986054880791723
# error:  0.30561330561330563
# f1:  0.7312614259597806
# precision : 0.6389776357827476
# recall : 0.8547008547008547
# ***********************
#  predicted False  predicted True
#              134             113  actual False
#               34             200   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.8392617449664429
# error:  0.1605351170568562
# f1:  0.8490566037735849
# precision : 0.8035714285714286
# recall : 0.9
# ***********************
#  predicted False  predicted True
#              348              99  actual False
#               45             405   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.6787230208625316
# error:  0.319910514541387
# f1:  0.7168316831683168
# precision : 0.6487455197132617
# recall : 0.8008849557522124
# ***********************
#  predicted False  predicted True
#              123              98  actual False
#               45             181   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.8448173005219984
# error:  0.15496098104793757
# f1:  0.8550573514077163
# precision : 0.8055009823182712
# recall : 0.9111111111111111
# ***********************
#  predicted False  predicted True
#              348              99  actual False
#               40             410   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.7030060328687331
# error:  0.30296127562642367
# f1:  0.7223382045929018
# precision : 0.6407407407407407
# recall : 0.8277511961722488
# ***********************
#  predicted False  predicted True
#              133              97  actual False
#               36             173   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.8593064876957495
# error:  0.14046822742474915
# f1:  0.86875
# precision : 0.8176470588235294
# recall : 0.9266666666666666
# ***********************
#  predicted False  predicted True
#              354              93  actual False
#               33             417   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.7231573655103067
# error:  0.27802690582959644
# f1:  0.7529880478087649
# precision : 0.6725978647686833
# recall : 0.8552036199095022
# ***********************
#  predicted False  predicted True
#              133              92  actual False
#               32             189   actual True
# <ipython-input-1-8f90cbef799c>:16: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   vec = np.fromstring(str_word_vec, dtype=float, sep=' ')
# RandomForestClassifier()
# All Results
# roc auc:  0.8593214019388516
# error:  0.14046822742474915
# f1:  0.8682008368200836
# precision : 0.8201581027667985
# recall : 0.9222222222222223
# ***********************
#  predicted False  predicted True
#              356              91  actual False
#               35             415   actual True
#
#
#
# Non Trivial Results
# roc auc:  0.7247706422018347
# error:  0.27522935779816515
# f1:  0.7570850202429149
# precision : 0.677536231884058
# recall : 0.8577981651376146
# ***********************
#  predicted False  predicted True
#              129              89  actual False
#               31             187   actual True
# # Positive Pairs: 0.1
# defaultdict(<class 'list'>, {'auc': [0.6684031904920388, 0.8040453403848068, 0.8207758144381443, 0.8283846495803042, 0.8307532666541274, 0.8352079691078341, 0.8387192660972815, 0.8416024860869854, 0.8419202087994034, 0.8494884414615957], 'error': [0.33169934640522875, 0.19583488285608033, 0.1790655509065551, 0.1714422310756972, 0.1690591297880253, 0.16460611470653871, 0.16107083100948133, 0.15820007437709185, 0.15785953177257525, 0.15027870680044592], 'precision': [0.6849112883466321, 0.7849134854109647, 0.7941293357718845, 0.7987012473410864, 0.7984937348847029, 0.8027865456106742, 0.802047350058618, 0.8066546839972406, 0.8032708341399797, 0.8078956023165864], 'recall': [0.6380727762803234, 0.8398319743019521, 0.8681679177092021, 0.8801143583227446, 0.8868050407709415, 0.8907473309608541, 0.9014452473596443, 0.9005930318754634, 0.9077777777777778, 0.9191111111111111], 'f1': [0.6551056407514084, 0.8112591932029695, 0.8294574628655108, 0.8374078758862477, 0.8403321705812513, 0.8444586078639099, 0.8488380923878529, 0.8510063429773407, 0.8522936087794106, 0.8598883228310461]})
# defaultdict(<class 'list'>, {'auc': [0.5203276855448326, 0.6345442218938121, 0.6576237687773545, 0.6719238113208206, 0.6742723234736989, 0.6797920384059583, 0.6869605694857547, 0.6929823509501478, 0.6942894183582687, 0.7095179322515157], 'error': [0.4799390083533418, 0.3652465714190978, 0.3424290770539589, 0.32798427210885683, 0.3253438063673746, 0.3197728167869358, 0.31284604064858135, 0.3069886853740111, 0.3063592089662329, 0.2922292166372061], 'precision': [0.5090459289940715, 0.6164947732175069, 0.6304875233846532, 0.6408372757098987, 0.6419835016961614, 0.6469769017044635, 0.648554997790102, 0.6543910479554579, 0.6511019329093483, 0.6580306739479058], 'recall': [0.4644405514903355, 0.7169748187864265, 0.7608362995639001, 0.783994963432535, 0.7943471764955831, 0.799296592242582, 0.8179682801567416, 0.8201007323495281, 0.8299119445746774, 0.8498785726548665], 'f1': [0.4792844785542419, 0.6625928601577247, 0.6894689260596223, 0.7051668005837902, 0.7100700105176538, 0.7150451610434234, 0.7234555956411639, 0.7277824123636178, 0.7295820779158967, 0.7416175822292449]})

# %%
non_trivial['auc']
# Out:
# [0.42134831460674155,
#  0.8887640449438202,
#  0.8786516853932584,
#  0.8876404494382022,
#  0.8820224719101124,
#  0.8786516853932584,
#  0.8853932584269664,
#  0.8943820224719101,
#  0.43258426966292135,
#  0.8831460674157303]
